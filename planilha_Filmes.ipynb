# %% [markdown]
# <a href="https://colab.research.google.com/github/F10rencio/Eletiva/blob/main/planilha_Filmes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# LEITURA DOS DADOS

# %%
df = pd.read_csv ('/movies.csv')

data.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df.shape
# Out:
# (9742, 3)

# %% [markdown]
# ORGANIZAÇÃO DOS DADOS

# %%
df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df.tail()
# Out:
#       movieId                                      title  \
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                genres
# 9737  Action|Animation|Comedy|Fantasy
# 9738         Animation|Comedy|Fantasy
# 9739                            Drama
# 9740                 Action|Animation
# 9741                           Comedy

# %%
df.sample(10)
# Out:
#       movieId                                              title  \
# 5468    26172                                 Point Blank (1967)
# 6200    45208                                          RV (2006)
# 6609    55765                           American Gangster (2007)
# 9154   147662           Return of the One-Armed Swordsman (1969)
# 4078     5818  Crime of Father Amaro, The (Crimen del padre A...
# 1339     1816                         Two Girls and a Guy (1997)
# 4626     6889                                Brother Bear (2003)
# 6011    37830          Final Fantasy VII: Advent Children (2004)
# 6090    42007                             Rumor Has It... (2005)
# 6280    47646                                    Idlewild (2006)
#
#                                          genres
# 5468                Action|Crime|Drama|Thriller
# 6200                  Adventure|Children|Comedy
# 6609                       Crime|Drama|Thriller
# 9154                           Action|Adventure
# ...

# %%
df.dtypes
# Out:
# movieId     int64
# title      object
# genres     object
# dtype: object

# %%
df.isna().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [movieId, title, genres]
# Index: []

# %%
df.nunique()
# Out:
# movieId    9742
# title      9737
# genres      951
# dtype: int64

# %% [markdown]
# Arrumando Texto das colunas

# %%
df = df.rename(columns={'movieId': 'ID Filmes'})

# %%
print(df.head())
# Out:
#    ID Filmes                               title  \
# 0          1                    Toy Story (1995)
# 1          2                      Jumanji (1995)
# 2          3             Grumpier Old Men (1995)
# 3          4            Waiting to Exhale (1995)
# 4          5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df = df.rename(columns={'title': 'Título'})

# %%
df = df.rename(columns={'genres': 'Gêneros'})

# %%
df.head()
# Out:
#    ID Filmes                              Título  \
# 0          1                    Toy Story (1995)
# 1          2                      Jumanji (1995)
# 2          3             Grumpier Old Men (1995)
# 3          4            Waiting to Exhale (1995)
# 4          5  Father of the Bride Part II (1995)
#
#                                        Gêneros
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df.to_csv('/movies.csv', index=False )

# %%
df.head()
# Out:
#    ID Filmes                              Título  \
# 0          1                    Toy Story (1995)
# 1          2                      Jumanji (1995)
# 2          3             Grumpier Old Men (1995)
# 3          4            Waiting to Exhale (1995)
# 4          5  Father of the Bride Part II (1995)
#
#                                        Gêneros
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
